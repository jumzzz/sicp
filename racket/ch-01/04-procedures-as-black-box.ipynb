# %% [markdown]
# ### Observation
#
# The entire `sqrt` program can be viewed as a cluster of procedures.
#
# ![image.png](attachment:image.png)
#
# - The details of how `square` is computed can be suppressed.
# - `square` is not quite a procedure but rather an abstaction of a procedure, a so called *procedural abstraction*

# %%
# Out:
# yes
